# %%
revenues = [120, 250, 80, 310, 95]
tax_rate = 0.18
discount_rate = 0.10

# %%
revenues = [120, 250, 80, 310, 95]
revenue_after_tax=[]
for value in revenues:
    revenue_after_tax.append(value*1.18)
    revenue_after_tax

# %%
print(revenue_after_tax)
# Out:
# [141.6, 295.0, 94.39999999999999, 365.79999999999995, 112.1]

# %%
revenue_after_tax
discount_rate = 0.10
revenue_after_discount=[]
revenue_after_discount=[value*(1-discount_rate) for value in revenue_after_tax]
print(revenue_after_discount)
# Out:
# [127.44, 265.5, 84.96, 329.21999999999997, 100.89]

# %%
revenue_after_discount
for value in revenue_after_discount:
    if value>100:
        print(True)
    else:
        print(False)
# Out:
# True
# True
# False
# True
# True

# %%
revenue_after_discount
for value in revenue_after_discount:
    if value>100 and value<200:
        print(True)
    elif value>200 and  value<300:
        print(True)
    else:
        print(False)
# Out:
# True
# True
# False
# False
# True

# %%
sales = [120, 250, 80, 310, 95]
avg_sales=(sum(sales)/len(sales))
print(avg_sales)
# Out:
# 171.0

# %%
sales = [120, 250, 80, 310, 95]

highest = sales[0]
for s in sales:
    if s > highest:
        highest = s
print(highest)
# Out:
# 310

# %%
len(sales)
# Out:
# 5

# %%
sales
for value in sales:
    if value > 150:
        print(len(sales))
# Out:
# 5
# 5

# %%
sales
count=sum(1 for s in sales if s > 150)
print(count)
# Out:
# 2

# %%
sales
revenue=[]
c=0.05
revenue=[value*(1+c)for value in sales]
print(revenue)
# Out:
# [126.0, 262.5, 84.0, 325.5, 99.75]

# %%
revenue
for v in revenue:
    if v > 250:
        print("Premium",v)
    elif 100< v <= 250:
        print("Standard",v)
    else:
        print("Low",v)
# Out:
# Standard 126.0
# Premium 262.5
# Low 84.0
# Premium 325.5
# Low 99.75

# %%
labels_segment=["Standard","Premium","Low","Premium","Low"]

# %%
premium_count = labels_segment.count("Premium")
print(premium_count)
# Out:
# 2

# %%
customer_ids = [1, 2, 3, 3, 4, 5, 5, 6]

# %%
len(customer_ids)
# Out:
# 8

# %%
set(customer_ids)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
len(set(customer_ids))
# Out:
# 6

# %%
list(set(customer_ids))
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
customer = {
    "name": "Anna",
    "revenue": 250,
    "city": "Yerevan"
}

# %%
customer["segment"]="Premium"
print(customer)
# Out:
# {'name': 'Anna', 'revenue': 250, 'city': 'Yerevan', 'segment': 'Premium'}

# %%
customer["revenue"]=300
print(customer)
# Out:
# {'name': 'Anna', 'revenue': 300, 'city': 'Yerevan', 'segment': 'Premium'}

# %%
del customer["city"]
print(customer)
# Out:
# {'name': 'Anna', 'revenue': 300, 'segment': 'Premium'}

# %%
for key in customer:
    print(key,customer[key])
# Out:
# name Anna
# revenue 300
# segment Premium

# %%
revenues = [120, 250, 80, 310, 95]
taxed_revenue=[r*0.9 for r in revenues]
print (taxed_revenue)
# Out:
# [108.0, 225.0, 72.0, 279.0, 85.5]

# %%
filtered_revenue=[r for r in revenues if r>100]
print(filtered_revenue)
# Out:
# [120, 250, 310]

# %%
labaled_revenue=["High" if r>200 else "Normal" for r in revenues]

# %%
print(labaled_revenue)
# Out:
# ['Normal', 'High', 'Normal', 'High', 'Normal']

# %%
import pandas as pd

data = {
    "revenue": revenues
}

df = pd.DataFrame(data)
df
# Out:
#    revenue
# 0      120
# 1      250
# 2       80
# 3      310
# 4       95

# %%
t = 0.18
df["revenue_after_tax"] = df["revenue"] * (1 +t)
df
# Out:
#    revenue  revenue_after_tax
# 0      120              141.6
# 1      250              295.0
# 2       80               94.4
# 3      310              365.8
# 4       95              112.1

# %%
df.loc[df["revenue_after_tax"]>150,"segment"]="High"
df.loc[df["revenue_after_tax"]<150,"segment"]="Low"
df
# Out:
#    revenue  revenue_after_tax segment
# 0      120              141.6     Low
# 1      250              295.0    High
# 2       80               94.4     Low
# 3      310              365.8    High
# 4       95              112.1     Low

# %%
df[df["revenue_after_tax"]>100]
# Out:
#    revenue  revenue_after_tax segment
# 0      120              141.6     Low
# 1      250              295.0    High
# 3      310              365.8    High
# 4       95              112.1     Low

# %%
df.drop("segment",axis=1)
# Out:
#    revenue  revenue_after_tax
# 0      120              141.6
# 1      250              295.0
# 2       80               94.4
# 3      310              365.8
# 4       95              112.1
